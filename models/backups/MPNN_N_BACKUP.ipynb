# %%
### TODO
#
# - clean the graph to simplify the problem
#   - FORMAT 1
#        - for nodes with multiple transactions between themselves, keep only one directed adge - remove all others. This edge will contain the number of transactions and the average amount of those transactions
#
#
#
#

# %%
import pandas as pd
import networkx as nx
import numpy as np

# Read in the CSV files
accounts_df = pd.read_csv("data/accounts.csv")
transactions_df = pd.read_csv("data/transactions.csv")

# Create a directed graph
graph = nx.MultiDiGraph()
graph2 = nx.DiGraph()

# Add nodes to the graph using the accounts DataFrame
for index, row in accounts_df.iterrows():
    graph.add_node(row["acct_id"], initial_deposit=row["initial_deposit"])
    graph2.add_node(row["acct_id"], initial_deposit=row["initial_deposit"])

# Add edges to the graph using the transactions DataFrame
for index, row in transactions_df.iterrows():
    graph.add_edge(row["orig_acct"], row["bene_acct"], base_amt=row["base_amt"], is_sar=row["is_sar"])

# Print out some information about the graph
print("Number of nodes:", graph.number_of_nodes())
print("Number of edges:", graph.number_of_edges())
# Out:
# Number of nodes: 1446
# Number of edges: 121457

# %%
'''
for node in graph.nodes:
    print(node, graph.nodes[node])
print("Edge information:")
for edge in graph.edges:
    print(edge, graph.edges[edge])
'''

for u in graph.nodes:
    graph2.nodes[u]["is_sar"] = False

for u in graph.nodes: #loop through nodes. Current node is u
    tsc_amts = []
    for v in graph.predecessors(u):#loop though in degree nodes v
        ### WRONG ###
        #e_v2u = graph.in_edges(v, data=True) #edges from 
        e_v2u = [(s, t, d) for (s, t, d) in graph.edges(v, data=True) if t == u]
        #print(e_v2u)
        #print(e_v2u)
        edge_tsc_amts = []
        is_sar = False
        if e_v2u:
            for edge in e_v2u: #for each edge from v to u
                
                src, dest, attrs = edge
                edge_tsc_amts.append(attrs["base_amt"])
                if attrs["is_sar"] == True:
                    is_sar = True
            
            #get stats on edges
            v2u_total = np.sum(edge_tsc_amts)
            v2u_mean = np.mean(edge_tsc_amts)
            v2u_min = np.min(edge_tsc_amts)
            v2u_max = np.max(edge_tsc_amts)
            v2u_std = np.std(edge_tsc_amts)
            v2u_is_sar = is_sar
            v2u_count = len(edge_tsc_amts)

            graph2.add_edge(v, u, total_tsc_amt=v2u_total, mean_tsc_amt=v2u_mean, min_tsc_amt=v2u_min, max_tsc_amt=v2u_max, std_tsc_amt=v2u_std, num_of_tsc=v2u_count, contains_is_sar_tsc=v2u_is_sar)
            
            if v2u_is_sar == True:
                graph2.nodes[u]["is_sar"] = True
                graph2.nodes[v]["is_sar"] = True
            

print("Number of nodes:", graph2.number_of_nodes())
print("Number of edges:", graph2.number_of_edges())
# Out:
# Number of nodes: 1446
# Number of edges: 6984

# %%
import matplotlib.pyplot as plt
nodes_df = pd.DataFrame.from_dict(dict(graph2.nodes(data=True)), orient='index')
nodes_df.to_csv('accounts_cleaned.csv')
#nodes_df.is_sar.hist()
#np.sum(np.isnan(nodes_df.is_sar.tolist()))
#b = np.array(nodes_df.is_sar.tolist())
#print(len(b[b==True]), len(b[b==False]),len(b[b==True]) + len(b[b==False]), len(b[b==True])/(len(b[b==True]) + len(b[b==False])))

edges_df = pd.DataFrame([(u, v, d['total_tsc_amt'], d['mean_tsc_amt'], d['min_tsc_amt'], d['max_tsc_amt'], d['std_tsc_amt'], d['num_of_tsc'], d['contains_is_sar_tsc']) for u, v, d in graph2.edges(data=True)], columns=['source', 'target', 'total_tsc_amt','mean_tsc_amt', 'min_tsc_amt', 'max_tsc_amt', 'std_tsc_amt', 'num_of_tscs', 'contains_is_sar_tsc'])
edges_df.to_csv('transactions_cleaned.csv')

# %%
print(nodes_df)
print(edges_df)
# Out:
#       initial_deposit  is_sar
# 0            96646.86   False
# 1            80707.36   False
# 2            52101.10   False
# 3            90324.40   False
# 4            91267.86   False
# ...               ...     ...
# 1441         61754.39   False
# 1442         88437.72   False
# 1443         84987.77   False
# 1444         50857.55   False
# 1445         75294.22   False
#
# [1446 rows x 2 columns]
#       source  target  total_tsc_amt  mean_tsc_amt  min_tsc_amt  max_tsc_amt  \
# 0          0      19       46768.99    563.481807        95.51       998.89
# 1          0      20       43773.90    527.396386         6.79       995.51
# 2          0     211        9541.32    454.348571       134.48       983.69
# 3          1      11       10305.92    515.296000       179.59       971.46
# 4          1      13       11016.91    550.845500       203.30       958.91
# ...      ...     ...            ...           ...          ...          ...
# 6979    1442      10       43147.67    519.851446       100.17       983.21
# 6980    1442      27       46182.96    537.011163        17.82       985.99
# 6981    1443     557       59569.59    578.345534       111.86       994.95
# 6982    1444     159       50857.13    565.079222        64.03       996.60
# 6983    1445       8       58875.12    571.603107       107.21       998.28
#
#       std_tsc_amt  num_of_tscs  contains_is_sar_tsc
# 0      254.792626           83                False
# 1      263.846581           83                False
# 2      267.739662           21                False
# 3      229.839776           20                False
# 4      219.441776           20                False
# ...           ...          ...                  ...
# 6979   251.010058           83                False
# 6980   297.671375           86                False
# 6981   248.455307          103                False
# 6982   269.042713           90                False
# 6983   265.228149          103                False
#
# [6984 rows x 9 columns]

# %%
# !pip3 install ConfigModel-MCMC
# Out:
# Collecting ConfigModel-MCMC
#   Using cached ConfigModel_MCMC-0.0.10-py3-none-any.whl (27 kB)
# Requirement already satisfied: numpy>=1.17.1 in /Users/julienschmidt/anaconda3/envs/GDL/lib/python3.10/site-packages (from ConfigModel-MCMC) (1.23.5)
# Requirement already satisfied: networkx>=2.4 in /Users/julienschmidt/anaconda3/envs/GDL/lib/python3.10/site-packages (from ConfigModel-MCMC) (2.7.1)
# Collecting numba==0.49.1
#   Using cached numba-0.49.1.tar.gz (2.0 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy>=1.4.1 in /Users/julienschmidt/anaconda3/envs/GDL/lib/python3.10/site-packages (from ConfigModel-MCMC) (1.10.0)
# Collecting arch==5.0.1
#   Using cached arch-5.0.1.tar.gz (937 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting python-igraph==0.9.6
#   Using cached python-igraph-0.9.6.tar.gz (3.6 MB)
#   Preparing metadata (setup.py) ... done
# Collecting tqdm==4.62.2
#   Using cached tqdm-4.62.2-py2.py3-none-any.whl (76 kB)
# Collecting property-cached>=1.6.4
#   Using cached property_cached-1.6.4-py2.py3-none-any.whl (7.8 kB)
# Collecting statsmodels>=0.11
#   Downloading statsmodels-0.13.5-cp310-cp310-macosx_10_9_x86_64.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 6.8 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: pandas>=1.0 in /Users/julienschmidt/anaconda3/envs/GDL/lib/python3.10/site-packages (from arch==5.0.1->ConfigModel-MCMC) (1.5.3)
# Collecting llvmlite<=0.33.0.dev0,>=0.31.0.dev0
#   Using cached llvmlite-0.32.1.tar.gz (104 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /Users/julienschmidt/anaconda3/envs/GDL/lib/python3.10/site-packages (from numba==0.49.1->ConfigModel-MCMC) (65.6.3)
# Collecting texttable>=1.6.2
#   Using cached texttable-1.6.7-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/julienschmidt/anaconda3/envs/GDL/lib/python3.10/site-packages (from pandas>=1.0->arch==5.0.1->ConfigModel-MCMC) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/julienschmidt/anaconda3/envs/GDL/lib/python3.10/site-packages (from pandas>=1.0->arch==5.0.1->ConfigModel-MCMC) (2022.7)
# Collecting patsy>=0.5.2
#   Using cached patsy-0.5.3-py2.py3-none-any.whl (233 kB)
# Requirement already satisfied: packaging>=21.3 in /Users/julienschmidt/anaconda3/envs/GDL/lib/python3.10/site-packages (from statsmodels>=0.11->arch==5.0.1->ConfigModel-MCMC) (23.0)
# Requirement already satisfied: six in /Users/julienschmidt/anaconda3/envs/GDL/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels>=0.11->arch==5.0.1->ConfigModel-MCMC) (1.16.0)
# Building wheels for collected packages: arch, numba, python-igraph, llvmlite
#   Building wheel for arch (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for arch (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [153 lines of output]
#       /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-build-env-l00hhzk0/overlay/lib/python3.10/site-packages/setuptools/dist.py:788: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#         warnings.warn(
#       /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-build-env-l00hhzk0/overlay/lib/python3.10/site-packages/setuptools/config/setupcfg.py:516: SetuptoolsDeprecationWarning: The license_file parameter is deprecated, use license_files instead.
#         warnings.warn(msg, warning_class)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-10.9-x86_64-cpython-310
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch
#       copying ./arch/conftest.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch
#       copying ./arch/_version.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch
#       copying ./arch/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch
#       copying ./arch/typing.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/compat
#       copying ./arch/compat/pandas.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/compat
#       copying ./arch/compat/numba.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/compat
#       copying ./arch/compat/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/compat
#       copying ./arch/compat/statsmodels.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/compat
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/bootstrap
#       copying ./arch/bootstrap/multiple_comparison.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/bootstrap
#       copying ./arch/bootstrap/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/bootstrap
#       copying ./arch/bootstrap/_samplers_python.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/bootstrap
#       copying ./arch/bootstrap/base.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/bootstrap
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/tests
#       copying ./arch/tests/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests
#       copying ./arch/tests/test_tester.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests
#       copying ./arch/tests/test_compat.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests
#       copying ./arch/tests/test_data.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests
#       copying ./arch/tests/test_examples.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/covariance
#       copying ./arch/covariance/kernel.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/covariance
#       copying ./arch/covariance/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/covariance
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/__future__
#       copying ./arch/__future__/_utility.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/__future__
#       copying ./arch/__future__/reindexing.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/__future__
#       copying ./arch/__future__/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/__future__
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/unitroot
#       copying ./arch/unitroot/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/unitroot
#       copying ./arch/unitroot/_shared.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/unitroot
#       copying ./arch/unitroot/cointegration.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/unitroot
#       copying ./arch/unitroot/_phillips_ouliaris.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/unitroot
#       copying ./arch/unitroot/unitroot.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/unitroot
#       copying ./arch/unitroot/_engle_granger.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/unitroot
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/univariate
#       copying ./arch/univariate/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/univariate
#       copying ./arch/univariate/distribution.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/univariate
#       copying ./arch/univariate/mean.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/univariate
#       copying ./arch/univariate/recursions_python.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/univariate
#       copying ./arch/univariate/volatility.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/univariate
#       copying ./arch/univariate/base.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/univariate
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/data
#       copying ./arch/data/utility.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data
#       copying ./arch/data/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/vendor
#       copying ./arch/vendor/property_cached.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/vendor
#       copying ./arch/vendor/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/vendor
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/utility
#       copying ./arch/utility/io.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/utility
#       copying ./arch/utility/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/utility
#       copying ./arch/utility/cov.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/utility
#       copying ./arch/utility/exceptions.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/utility
#       copying ./arch/utility/testing.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/utility
#       copying ./arch/utility/array.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/utility
#       copying ./arch/utility/timeseries.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/utility
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/bootstrap
#       copying ./arch/tests/bootstrap/test_multiple_comparison.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/bootstrap
#       copying ./arch/tests/bootstrap/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/bootstrap
#       copying ./arch/tests/bootstrap/test_block_length.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/bootstrap
#       copying ./arch/tests/bootstrap/test_bootstrap.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/bootstrap
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/covariance
#       copying ./arch/tests/covariance/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/covariance
#       copying ./arch/tests/covariance/test_covariance.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/covariance
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/unitroot
#       copying ./arch/tests/unitroot/test_phillips_ouliaris.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/unitroot
#       copying ./arch/tests/unitroot/test_engle_granger.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/unitroot
#       copying ./arch/tests/unitroot/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/unitroot
#       copying ./arch/tests/unitroot/test_dynamic_ols.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/unitroot
#       copying ./arch/tests/unitroot/test_fmols_ccr.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/unitroot
#       copying ./arch/tests/unitroot/cointegration_data.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/unitroot
#       copying ./arch/tests/unitroot/test_unitroot.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/unitroot
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/univariate
#       copying ./arch/tests/univariate/test_rescale.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/univariate
#       copying ./arch/tests/univariate/test_volatility.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/univariate
#       copying ./arch/tests/univariate/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/univariate
#       copying ./arch/tests/univariate/test_arch_in_mean.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/univariate
#       copying ./arch/tests/univariate/test_forecast.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/univariate
#       copying ./arch/tests/univariate/test_recursions.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/univariate
#       copying ./arch/tests/univariate/test_variance_forecasting.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/univariate
#       copying ./arch/tests/univariate/test_distribution.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/univariate
#       copying ./arch/tests/univariate/test_mean.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/univariate
#       copying ./arch/tests/univariate/test_moment.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/univariate
#       copying ./arch/tests/univariate/test_base.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/univariate
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/utility
#       copying ./arch/tests/utility/test_timeseries.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/utility
#       copying ./arch/tests/utility/test_cov.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/utility
#       copying ./arch/tests/utility/test_array.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/utility
#       copying ./arch/tests/utility/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/utility
#       copying ./arch/tests/utility/test_utility.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/utility
#       copying ./arch/tests/utility/test_io.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/utility
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/unitroot/data
#       copying ./arch/tests/unitroot/data/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/unitroot/data
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/unitroot/critical_values
#       copying ./arch/unitroot/critical_values/dfgls.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/unitroot/critical_values
#       copying ./arch/unitroot/critical_values/zivot_andrews.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/unitroot/critical_values
#       copying ./arch/unitroot/critical_values/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/unitroot/critical_values
#       copying ./arch/unitroot/critical_values/engle_granger.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/unitroot/critical_values
#       copying ./arch/unitroot/critical_values/phillips_ouliaris.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/unitroot/critical_values
#       copying ./arch/unitroot/critical_values/kpss.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/unitroot/critical_values
#       copying ./arch/unitroot/critical_values/dickey_fuller.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/unitroot/critical_values
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/data/vix
#       copying ./arch/data/vix/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data/vix
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/data/nasdaq
#       copying ./arch/data/nasdaq/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data/nasdaq
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/data/core_cpi
#       copying ./arch/data/core_cpi/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data/core_cpi
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/data/default
#       copying ./arch/data/default/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data/default
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/data/sp500
#       copying ./arch/data/sp500/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data/sp500
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/data/frenchdata
#       copying ./arch/data/frenchdata/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data/frenchdata
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/data/binary
#       copying ./arch/data/binary/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data/binary
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/data/crude
#       copying ./arch/data/crude/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data/crude
#       creating build/lib.macosx-10.9-x86_64-cpython-310/arch/data/wti
#       copying ./arch/data/wti/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data/wti
#       copying ./arch/py.typed -> build/lib.macosx-10.9-x86_64-cpython-310/arch
#       copying ./arch/tests/unitroot/data/zivot-andrews.csv -> build/lib.macosx-10.9-x86_64-cpython-310/arch/tests/unitroot/data
#       copying ./arch/data/vix/vix.csv.gz -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data/vix
#       copying ./arch/data/nasdaq/nasdaq.csv.gz -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data/nasdaq
#       copying ./arch/data/core_cpi/core-cpi.csv.gz -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data/core_cpi
#       copying ./arch/data/default/default.csv.gz -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data/default
#       copying ./arch/data/sp500/sp500.csv.gz -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data/sp500
#       copying ./arch/data/frenchdata/frenchdata.csv.gz -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data/frenchdata
#       copying ./arch/data/binary/binary.csv.gz -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data/binary
#       copying ./arch/data/crude/crude.csv.gz -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data/crude
#       copying ./arch/data/wti/wti.csv.gz -> build/lib.macosx-10.9-x86_64-cpython-310/arch/data/wti
#       UPDATING build/lib.macosx-10.9-x86_64-cpython-310/arch/_version.py
#       set build/lib.macosx-10.9-x86_64-cpython-310/arch/_version.py to '5.0.1'
#       running build_ext
#       building 'arch.univariate.recursions' extension
#       creating build/temp.macosx-10.9-x86_64-cpython-310
#       creating build/temp.macosx-10.9-x86_64-cpython-310/arch
#       creating build/temp.macosx-10.9-x86_64-cpython-310/arch/univariate
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/julienschmidt/anaconda3/envs/GDL/include -fPIC -O2 -isystem /Users/julienschmidt/anaconda3/envs/GDL/include -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -I/private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-build-env-l00hhzk0/overlay/lib/python3.10/site-packages/numpy/core/include -I/Users/julienschmidt/anaconda3/envs/GDL/include/python3.10 -c ./arch/univariate/recursions.c -o build/temp.macosx-10.9-x86_64-cpython-310/./arch/univariate/recursions.o
#       In file included from ./arch/univariate/recursions.c:25:
#       /Users/julienschmidt/anaconda3/envs/GDL/include/python3.10/Python.h:25:10: fatal error: 'stdio.h' file not found
#       #include <stdio.h>
#                ^~~~~~~~~
#       1 error generated.
#       error: command '/usr/local/opt/llvm/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for arch
#   Building wheel for numba (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [852 lines of output]
#       /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/numba_d294d8665c5849f091ba83caccd683cc/setup.py:94: DeprecationWarning:
#
#         `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#         of the deprecation of `distutils` itself. It will be removed for
#         Python >= 3.12. For older Python versions it will remain present.
#         It is recommended to use `setuptools < 60.0` for those Python versions.
#         For more details, see:
#           https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#         import numpy.distutils.misc_util as np_misc
#       TBB not found
#       OpenMP disabled
#       running bdist_wheel
#       running build
#       got version from file /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/numba_d294d8665c5849f091ba83caccd683cc/numba/_version.py {'version': '0.49.1', 'full': 'd2cac8597ad2aa4074147d9c7595f5b5e9919901'}
#       running build_py
#       creating build
#       creating build/lib.macosx-10.9-x86_64-cpython-310
#       creating build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/dispatcher.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/serialize.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/funcdesc.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/postproc.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/stencil.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/transforms.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/compiler_machinery.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/tracing.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/config.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/compiler.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/withcontexts.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/analysis.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/_version.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/unicode.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/inline_closurecall.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/ir_utils.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/pylowering.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/parfor.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/lowering.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/stencilparfor.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/object_mode_passes.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/typeconv.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/sigutils.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/numpy_support.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/ir.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/itanium_mangler.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/array_analysis.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/consts.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/generators.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/appdirs.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/charseq.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/listobject.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/interpreter.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/caching.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/unicode_support.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/utils.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/debuginfo.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/entrypoints.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/typeinfer.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/errors.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/typed_passes.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/bytecode.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/byteflow.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/untyped_passes.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/dataflow.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/callwrapper.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/dictobject.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/annotations.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/typedobjectutils.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/special.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/__main__.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/controlflow.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/cgutils.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/runtests.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/pythonapi.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/extending.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/npdatetime.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/compiler_lock.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       copying numba/decorators.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba
#       creating build/lib.macosx-10.9-x86_64-cpython-310/numba/rewrites
#       copying numba/rewrites/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/rewrites
#       creating build/lib.macosx-10.9-x86_64-cpython-310/numba/misc
#       copying numba/misc/literal.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/misc
#       copying numba/misc/quicksort.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/misc
#       copying numba/misc/numba_entry.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/misc
#       copying numba/misc/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/misc
#       copying numba/misc/inspection.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/misc
#       copying numba/misc/cffiimpl.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/misc
#       copying numba/misc/appdirs.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/misc
#       copying numba/misc/findlib.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/misc
#       copying numba/misc/gdb_hook.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/misc
#       copying numba/misc/dummyarray.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/misc
#       copying numba/misc/mergesort.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/misc
#       copying numba/misc/timsort.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/misc
#       copying numba/misc/special.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/misc
#       copying numba/misc/dump_style.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/misc
#       creating build/lib.macosx-10.9-x86_64-cpython-310/numba/experimental
#       copying numba/experimental/function_type.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/experimental
#       copying numba/experimental/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/experimental
#       creating build/lib.macosx-10.9-x86_64-cpython-310/numba/types
#       copying numba/types/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/types
#       creating build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/fastmathpass.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/dispatcher.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/serialize.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/funcdesc.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/postproc.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/options.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/transforms.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/compiler_machinery.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/tracing.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/optional.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/ccallback.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/config.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/compiler.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/withcontexts.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/analysis.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/inline_closurecall.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/ir_utils.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/registry.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/imputils.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/pylowering.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/externals.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/cpu.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/lowering.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/callconv.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/object_mode_passes.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/sigutils.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/ssa.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/ir.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/itanium_mangler.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/boxing.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/consts.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/intrinsics.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/generators.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/descriptors.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/interpreter.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/caching.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/utils.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/debuginfo.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/cpu_options.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/entrypoints.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/typeinfer.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/errors.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/typed_passes.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/bytecode.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/byteflow.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/untyped_passes.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/dataflow.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/callwrapper.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/codegen.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/controlflow.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/base.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/cgutils.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/pythonapi.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/extending.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/compiler_lock.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       copying numba/core/decorators.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/core
#       creating build/lib.macosx-10.9-x86_64-cpython-310/numba/targets
#       copying numba/targets/setobj.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/targets
#       copying numba/targets/options.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/targets
#       copying numba/targets/ufunc_db.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/targets
#       copying numba/targets/registry.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/targets
#       copying numba/targets/imputils.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/targets
#       copying numba/targets/builtins.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/targets
#       copying numba/targets/cpu.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/targets
#       copying numba/targets/callconv.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/targets
#       copying numba/targets/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/targets
#       copying numba/targets/slicing.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/targets
#       copying numba/targets/listobj.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/targets
#       copying numba/targets/boxing.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/targets
#       copying numba/targets/arraymath.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/targets
#       copying numba/targets/arrayobj.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/targets
#       copying numba/targets/hashing.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/targets
#       copying numba/targets/npdatetime.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/targets
#       creating build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/dispatcher.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/descriptor.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/printimpl.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/libdevice.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/device_init.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/compiler.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/intrinsic_wrapper.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/initialize.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/cuda_paths.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/simulator_init.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/envvars.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/random.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/api.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/stubs.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/vectorizers.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/args.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/target.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/cudamath.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/errors.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/cudaimpl.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/nvvmutils.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/testing.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/cudadecl.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/codegen.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       copying numba/cuda/decorators.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/cuda
#       creating build/lib.macosx-10.9-x86_64-cpython-310/numba/stencils
#       copying numba/stencils/stencil.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/stencils
#       copying numba/stencils/stencilparfor.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/stencils
#       copying numba/stencils/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/stencils
#       creating build/lib.macosx-10.9-x86_64-cpython-310/numba/pycc
#       copying numba/pycc/cc.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/pycc
#       copying numba/pycc/compiler.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/pycc
#       copying numba/pycc/llvm_types.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/pycc
#       copying numba/pycc/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/pycc
#       copying numba/pycc/platform.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/pycc
#       copying numba/pycc/decorators.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/pycc
#       creating build/lib.macosx-10.9-x86_64-cpython-310/numba/runtime
#       copying numba/runtime/nrt.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/runtime
#       copying numba/runtime/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/runtime
#       creating build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_support.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_map_filter_reduce.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_llvm_version_check.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_builtins.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_jitmethod.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_inlining.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_array_manipulation.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_dictobject.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_dummyarray.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_linalg.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_function_type.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/parfors_cache_usecases.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_threadsafety.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/cfunc_cache_usecases.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/overload_usecases.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/enum_usecases.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_debuginfo.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_func_lifetime.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_typeinfer.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_unicode.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_return_values.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_parallel_backend.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_nrt.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_warnings.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_typenames.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_moved_modules.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/orphaned_semaphore_usecase.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_mangling.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_npdatetime.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_fancy_indexing.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_practical_lowering_issues.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/support.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_print.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_parfors_passes.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_ssa.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_debug.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_interproc.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_typeconv.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_np_functions.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_typedobjectutils.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_tracing.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_ir_inlining.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/usecases.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_vectorization_type_inference.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/matmul_usecase.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_make_function_to_jit_function.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/complex_usecases.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_array_exprs.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_python_int.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_jitclasses.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_polynomial.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_wrapper.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_obj_lifetime.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_intwidth.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_extending.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_remove_dead.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/serialize_usecases.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_unsafe_intrinsics.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_literal_dispatch.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_listobject.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_del.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_gil.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_array_constants.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/cffi_usecases.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_numbers.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_slices.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_mandelbrot.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_numpy_support.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/compile_with_pycc.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_ir.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_deprecations.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_looplifting.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_storeslice.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/recursion_usecases.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_generators.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/dummy_module.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_recursion.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_operators.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_dictimpl.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_analysis.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_maxmin.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_exceptions.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_comprehension.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/ctypes_usecases.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_listimpl.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_locals.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_dicts.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_optional.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_mathlib.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_ir_utils.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_numberctor.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_globals.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_typingerror.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_object_mode.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_copy_propagate.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_ctypes.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_typeof.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_usecases.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_auto_constants.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_cffi.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_try_except.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
#       copying numba/tests/test_sort.py -> build/lib.macosx-10.9-x86_64-cpython-310/numba/tests
# ...
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_interrupt.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_complex.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_matching.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_heap.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_matrix.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_qsort.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_constants.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_interface.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_cocitation.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_progress.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_flow.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_error.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_psumtree.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_sparsemat.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_layout.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_games.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_pmt_off.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_vector_pmt.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_constructors.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_statusbar.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_cohesive_blocks.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_blas.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_arpack.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_matrix_pmt.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_stack_pmt.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_types.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_topology.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_pmt.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_array_pmt.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_memory.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_epidemics.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_operators.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_adjlist.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_dqueue.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_mixing.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_visitor.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_motifs.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_heap_pmt.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_graphlets.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_cliques.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_vector.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_spmatrix.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_microscopic_update.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_graphicality.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_components.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_lsap.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_random.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_structural.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_lapack.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_dqueue_pmt.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_community.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_transitivity.h
#       -- Up-to-date: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_export.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_version.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/include/igraph/igraph_threading.h
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/lib/pkgconfig/igraph.pc
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/lib/cmake/igraph/igraph-config.cmake
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/lib/cmake/igraph/igraph-config-version.cmake
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/lib/cmake/igraph/igraph-targets.cmake
#       -- Installing: /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/python-igraph_8aa7195094e84beebe5497a80659979d/vendor/install/igraph/lib/cmake/igraph/igraph-targets-release.cmake
#       Found igraph as static library in vendor/install/igraph/lib/libigraph.a.
#       Build type: dynamic extension with vendored igraph source
#       Include path: vendor/install/igraph/include/igraph
#       Library path: vendor/install/igraph/lib /usr/local/lib /usr/lib
#       Runtime library path:
#       Linked dynamic libraries: xml2 z omp
#       Linked static libraries: vendor/install/igraph/lib/libigraph.a
#       Extra compiler options:
#       Extra linker options:
#       building 'igraph._igraph' extension
#       creating build/temp.macosx-10.9-x86_64-cpython-310
#       creating build/temp.macosx-10.9-x86_64-cpython-310/src
#       creating build/temp.macosx-10.9-x86_64-cpython-310/src/_igraph
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/julienschmidt/anaconda3/envs/GDL/include -fPIC -O2 -isystem /Users/julienschmidt/anaconda3/envs/GDL/include -Ivendor/install/igraph/include/igraph -I/Users/julienschmidt/anaconda3/envs/GDL/include/python3.10 -c src/_igraph/arpackobject.c -o build/temp.macosx-10.9-x86_64-cpython-310/src/_igraph/arpackobject.o
#       In file included from src/_igraph/arpackobject.c:23:
#       In file included from src/_igraph/arpackobject.h:26:
#       /Users/julienschmidt/anaconda3/envs/GDL/include/python3.10/Python.h:25:10: fatal error: 'stdio.h' file not found
#       #include <stdio.h>
#                ^~~~~~~~~
#       1 error generated.
#       error: command '/usr/local/opt/llvm/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for python-igraph
#   Running setup.py clean for python-igraph
#   Building wheel for llvmlite (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       running bdist_wheel
#       /Users/julienschmidt/anaconda3/envs/GDL/bin/python /private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/llvmlite_c61f9f61f36a46768ab0f5af09fb681d/ffi/build.py
#       LLVM version... 13.0.0
#
#       Traceback (most recent call last):
#         File "/private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/llvmlite_c61f9f61f36a46768ab0f5af09fb681d/ffi/build.py", line 192, in <module>
#           main()
#         File "/private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/llvmlite_c61f9f61f36a46768ab0f5af09fb681d/ffi/build.py", line 186, in main
#           main_posix('osx', '.dylib')
#         File "/private/var/folders/zd/rszhwpkn75xg5_5yqhthxygh0000gn/T/pip-install-7wz9i1ks/llvmlite_c61f9f61f36a46768ab0f5af09fb681d/ffi/build.py", line 144, in main_posix
#           raise RuntimeError(msg)
#       RuntimeError: Building llvmlite requires LLVM 7.0.x, 7.1.x or 8.0.x, got '13.0.0'. Be sure to set LLVM_CONFIG to the right executable path.
#       Read the documentation at http://llvmlite.pydata.org/ for more information about building llvmlite.
#
#       error: command '/Users/julienschmidt/anaconda3/envs/GDL/bin/python' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for llvmlite
#   Running setup.py clean for llvmlite
# Failed to build arch numba python-igraph llvmlite
# ERROR: Could not build wheels for arch, which is required to install pyproject.toml-based projects

# %%
import basictest as bt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import basictest as bt
#
# File ~/Development/School/MasterThesis/Models/Simple_MPNN/basictest.py:5
#       3 from collections import Counter
#       4 import random as rd
# ----> 5 from configModel import configurationModel
#       6 import networkx as nx
#       7 from math import ceil
#
# ModuleNotFoundError: No module named 'configModel'

# %%
accounts_df = pd.read_csv("accounts_cleaned.csv")
transactions_df = pd.read_csv("transactions_cleaned.csv")

# %%
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)
# Helper function for visualization.
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from torch_geometric.transforms import NormalizeFeatures

def visualize(h, color):
    z = TSNE(n_components=2, learning_rate='auto',
             init='random').fit_transform(h.detach().cpu().numpy())

    plt.figure(figsize=(10,10))
    plt.xticks([])
    plt.yticks([])

    plt.scatter(z[:, 0], z[:, 1], s=70, c=color, cmap="Set2")
    plt.show()

def print_model_size(model):
    tot = sum([p.numel() for p in model.parameters() if p.requires_grad])
    out = f"Number of model ({model.__class__.__name__}) parameters:{tot:10d}"
    print("=" * len(out))
    print(out)
# Out:
# 2.0.0

# %%
from torch.utils.data import random_split
# Define your graph
x = torch.nn.functional.normalize(torch.tensor(nodes_df.initial_deposit.to_numpy()).unsqueeze(dim=1),dim=0).to(torch.float32)  # (n x features)
edge_index =  torch.stack([torch.tensor(edges_df.source.to_numpy()),torch.tensor(edges_df.target.to_numpy())],dim=-1).T  # Define your edge index
edge_attr = torch.nn.functional.normalize(torch.tensor(np.array(edges_df[['total_tsc_amt','mean_tsc_amt', 'min_tsc_amt', 'max_tsc_amt', 'std_tsc_amt', 'num_of_tscs', 'contains_is_sar_tsc']].values,dtype='float32')),dim=0) # edge features
y =  torch.tensor(nodes_df.is_sar.to_numpy().astype(int)) # target values

train_size = int(0.6 * len(y))  # 60% of the dataset for training
val_size = int(0.2 * len(y))    # 20% of the dataset for validation
test_size = len(y) - train_size - val_size  # Remaining 20% for testing

train_dataset, val_dataset, test_dataset = random_split(y, [train_size, val_size, test_size])

# Create masks for train, validation, and test sets
train_mask = torch.zeros(len(y), dtype=torch.bool)
val_mask = torch.zeros(len(y), dtype=torch.bool)
test_mask = torch.zeros(len(y), dtype=torch.bool)

train_mask[train_dataset.indices] = True
val_mask[val_dataset.indices] = True
test_mask[test_dataset.indices] = True

# %%
edge_attr.dtype
# Out:
# torch.float32

# %%
from torch_geometric.data import Data
# Load your data into PyTorch Geometric's Data class
data = Data(x=x, edge_index=edge_index, edge_attr=edge_attr, y=y,train_mask=train_mask, val_mask=val_mask, test_mask=test_mask)

# %%
# Gather some statistics about the graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')

print('==============================')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
print(f'Is weighted: {data.edge_weight is not None}')

print('==============================')
print(f'Number of training nodes: {data.train_mask.sum()}')
print(f'Training node label rate: {int(data.train_mask.sum()) / data.num_nodes:.2f}')
# Out:
# Number of nodes: 1446
# Number of edges: 6984
# Average node degree: 4.83
# ==============================
# Has isolated nodes: True
# Has self-loops: False
# Is undirected: False
# Is weighted: False
# ==============================
# Number of training nodes: 867
# Training node label rate: 0.60

# %%
import torch

from torch.nn import Linear
from torch_geometric.nn import MessagePassing
from torch_geometric.utils import degree


def random_walk_matrix(edge_index, num_nodes: int = None):
    source, target = edge_index[0], edge_index[1]
    in_deg = degree(target, num_nodes=num_nodes)   # D
    edge_weight = 1 / in_deg[target]               # D^-1 A
    return edge_index, edge_weight


class MPNN(MessagePassing):
    def __init__(self, in_channels: int, out_channels: int):
        super().__init__(aggr="add")                         # "sum" aggregation
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.lin_message = Linear(in_channels, out_channels, # weights 𝚯_1
                                  bias=False)
        self.lin_update = Linear(in_channels, out_channels,  # weights 𝚯_2
                                 bias=True)                  # the bias vector 𝐛

    def forward(self, x, edge_index, edge_weight=None):
        # 0. if GSO not already computed, compute it here
        if edge_weight is None:
          _, edge_weight = random_walk_matrix(edge_index)
        # 1. m_j→𝑖 = x_j𝚯_1
        m_ji = self.lin_message(x)  # we can project here with isotropic GNNs
        # 2. m_𝑖 = add(ã_ji ⋅ m_j→𝑖)_j∈𝑁(i)
        m_i = self.propagate(edge_index, m=m_ji, edge_weight=edge_weight)
        # 3. h_𝑖 = tanh(x_i𝚯_2 + m_i + 𝐛)
        h_i = torch.tanh(self.lin_update(x) + m_i)
        return h_i

    def message(self, m_j, edge_weight):
        return edge_weight.view(-1, 1) * m_j  # ã_ji ⋅ m_j→𝑖

# %%
gso_index, gso_weight = random_walk_matrix(data.edge_index, data.num_nodes)
print(f"Edge weights: {gso_weight}")
print(gso_index)
# Out:
# Edge weights: tensor([0.0123, 0.0128, 0.3333,  ..., 0.5000, 0.1250, 0.0204])
# tensor([[   0,    0,    0,  ..., 1443, 1444, 1445],
#         [  19,   20,  211,  ...,  557,  159,    8]])

# %%
a = torch.tensor([0,1,2,3,0,0])
deg = degree(a, num_nodes=None)
deg[a] #UNUSUAL BEHAVIOUR I DID NOT KNOW ABOUT
# Out:
# tensor([3., 1., 1., 1., 3., 3.])

# %%
import torch

from torch.nn import Linear

HIDDEN_SIZE = 16 #@param
NUM_LAYERS = 8 #@param

dataset_num_features = 1
dataset_num_classes = 2

class GNNModel(torch.nn.Module):

    def __init__(self, hidden_size: int,
                 num_layers: int = 1):
        super().__init__()
        torch.manual_seed(12345)

        self.mpnns = torch.nn.ModuleList()
        for l in range(num_layers):
            in_size = dataset_num_features if l == 0 else hidden_size
            mpnn = MPNN(in_channels=in_size, out_channels=hidden_size)
            self.mpnns.append(mpnn)

        self.lin_out = Linear(hidden_size, dataset_num_classes)
    
    def forward(self, x, edge_index, edge_weight=None):
        # Message-passing: transform node features based on neighbors
        for mpnn in self.mpnns:
            x = mpnn(x, edge_index, edge_weight)
        # Decoder: post-process extracted features
        out = self.lin_out(x)
        return out

model = GNNModel(HIDDEN_SIZE, NUM_LAYERS)
print(model)
print_model_size(model)
# Out:
# GNNModel(
#   (mpnns): ModuleList(
#     (0): MPNN(1, 16)
#     (1-7): 7 x MPNN(16, 16)
#   )
#   (lin_out): Linear(in_features=16, out_features=2, bias=True)
# )
# ================================================
# Number of model (GNNModel) parameters:      3778

# %%
model = GNNModel(HIDDEN_SIZE, NUM_LAYERS)
model.eval()

out = model(data.x, data.edge_index)
visualize(out, color=data.y)

# %%
sum(data.y.isnan())
# Out:
# tensor(0)

# %%
from IPython.display import Javascript  # Restrict height of output cell.
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 100})'''))

model = GNNModel(HIDDEN_SIZE, NUM_LAYERS)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)

def train():
      model.train()
      optimizer.zero_grad()
      # We now give as input also the graph connectivity
      out = model(data.x, gso_index, gso_weight)
      print(len(out[data.train_mask]),len(data.y[data.train_mask]))
      loss = criterion(out[data.train_mask], data.y[data.train_mask])
      loss.backward()
      optimizer.step()
      return loss

def test(mask):
      model.eval()
      out = model(data.x, gso_index, gso_weight)
      pred = out.argmax(dim=1)
      test_correct = pred[mask] == data.y[mask]
      test_acc = int(test_correct.sum()) / int(mask.sum())
      return test_acc, out, pred

for epoch in range(1, 201):
    train_loss = train()
    val_loss, _, _ = test(data.val_mask)
    print(f'Epoch: {epoch:03d} - Training loss: {train_loss:.4f} - '
          f'Validation accuracy: {val_loss * 100:.2f}%')
# Out:
# 867 867
# Epoch: 001 - Training loss: 0.7180 - Validation accuracy: 94.12%
# 867 867
# Epoch: 002 - Training loss: 0.5876 - Validation accuracy: 94.12%
# 867 867
# Epoch: 003 - Training loss: 0.4782 - Validation accuracy: 94.12%
# 867 867
# Epoch: 004 - Training loss: 0.3766 - Validation accuracy: 94.12%
# 867 867
# Epoch: 005 - Training loss: 0.3028 - Validation accuracy: 94.12%
# 867 867
# Epoch: 006 - Training loss: 0.2571 - Validation accuracy: 94.12%
# 867 867
# Epoch: 007 - Training loss: 0.2291 - Validation accuracy: 94.12%
# 867 867
# Epoch: 008 - Training loss: 0.2118 - Validation accuracy: 94.12%
# 867 867
# Epoch: 009 - Training loss: 0.2019 - Validation accuracy: 94.12%
# 867 867
# Epoch: 010 - Training loss: 0.1968 - Validation accuracy: 94.12%
# 867 867
# Epoch: 011 - Training loss: 0.1945 - Validation accuracy: 94.12%
# 867 867
# Epoch: 012 - Training loss: 0.1938 - Validation accuracy: 94.12%
# 867 867
# Epoch: 013 - Training loss: 0.1937 - Validation accuracy: 94.12%
# 867 867
# Epoch: 014 - Training loss: 0.1938 - Validation accuracy: 94.12%
# 867 867
# Epoch: 015 - Training loss: 0.1938 - Validation accuracy: 94.12%
# 867 867
# Epoch: 016 - Training loss: 0.1935 - Validation accuracy: 94.12%
# 867 867
# Epoch: 017 - Training loss: 0.1929 - Validation accuracy: 94.12%
# 867 867
# Epoch: 018 - Training loss: 0.1921 - Validation accuracy: 94.12%
# 867 867
# Epoch: 019 - Training loss: 0.1910 - Validation accuracy: 94.12%
# 867 867
# Epoch: 020 - Training loss: 0.1898 - Validation accuracy: 94.12%
# 867 867
# Epoch: 021 - Training loss: 0.1885 - Validation accuracy: 94.12%
# 867 867
# Epoch: 022 - Training loss: 0.1871 - Validation accuracy: 94.12%
# 867 867
# Epoch: 023 - Training loss: 0.1859 - Validation accuracy: 94.12%
# 867 867
# Epoch: 024 - Training loss: 0.1847 - Validation accuracy: 94.12%
# 867 867
# Epoch: 025 - Training loss: 0.1838 - Validation accuracy: 94.12%
# 867 867
# Epoch: 026 - Training loss: 0.1830 - Validation accuracy: 94.12%
# 867 867
# Epoch: 027 - Training loss: 0.1825 - Validation accuracy: 94.12%
# 867 867
# Epoch: 028 - Training loss: 0.1821 - Validation accuracy: 94.12%
# 867 867
# Epoch: 029 - Training loss: 0.1819 - Validation accuracy: 94.12%
# 867 867
# Epoch: 030 - Training loss: 0.1818 - Validation accuracy: 94.12%
# 867 867
# Epoch: 031 - Training loss: 0.1817 - Validation accuracy: 94.12%
# 867 867
# Epoch: 032 - Training loss: 0.1815 - Validation accuracy: 94.12%
# 867 867
# Epoch: 033 - Training loss: 0.1813 - Validation accuracy: 94.12%
# 867 867
# Epoch: 034 - Training loss: 0.1809 - Validation accuracy: 94.12%
# 867 867
# Epoch: 035 - Training loss: 0.1804 - Validation accuracy: 94.12%
# 867 867
# Epoch: 036 - Training loss: 0.1800 - Validation accuracy: 94.12%
# 867 867
# Epoch: 037 - Training loss: 0.1795 - Validation accuracy: 94.12%
# 867 867
# Epoch: 038 - Training loss: 0.1792 - Validation accuracy: 94.12%
# 867 867
# Epoch: 039 - Training loss: 0.1789 - Validation accuracy: 94.12%
# 867 867
# Epoch: 040 - Training loss: 0.1788 - Validation accuracy: 94.12%
# 867 867
# Epoch: 041 - Training loss: 0.1788 - Validation accuracy: 94.12%
# 867 867
# Epoch: 042 - Training loss: 0.1787 - Validation accuracy: 94.12%
# 867 867
# Epoch: 043 - Training loss: 0.1786 - Validation accuracy: 94.12%
# 867 867
# Epoch: 044 - Training loss: 0.1783 - Validation accuracy: 94.12%
# 867 867
# Epoch: 045 - Training loss: 0.1780 - Validation accuracy: 94.12%
# 867 867
# Epoch: 046 - Training loss: 0.1778 - Validation accuracy: 94.12%
# 867 867
# Epoch: 047 - Training loss: 0.1775 - Validation accuracy: 94.12%
# 867 867
# Epoch: 048 - Training loss: 0.1774 - Validation accuracy: 94.12%
# 867 867
# Epoch: 049 - Training loss: 0.1773 - Validation accuracy: 94.12%
# 867 867
# Epoch: 050 - Training loss: 0.1772 - Validation accuracy: 94.12%
# 867 867
# Epoch: 051 - Training loss: 0.1771 - Validation accuracy: 94.12%
# 867 867
# Epoch: 052 - Training loss: 0.1770 - Validation accuracy: 94.12%
# 867 867
# Epoch: 053 - Training loss: 0.1769 - Validation accuracy: 94.12%
# 867 867
# Epoch: 054 - Training loss: 0.1768 - Validation accuracy: 94.12%
# 867 867
# Epoch: 055 - Training loss: 0.1767 - Validation accuracy: 94.12%
# 867 867
# Epoch: 056 - Training loss: 0.1766 - Validation accuracy: 94.12%
# 867 867
# Epoch: 057 - Training loss: 0.1765 - Validation accuracy: 94.12%
# 867 867
# Epoch: 058 - Training loss: 0.1764 - Validation accuracy: 94.12%
# 867 867
# Epoch: 059 - Training loss: 0.1763 - Validation accuracy: 94.12%
# 867 867
# Epoch: 060 - Training loss: 0.1763 - Validation accuracy: 94.12%
# 867 867
# Epoch: 061 - Training loss: 0.1762 - Validation accuracy: 94.12%
# 867 867
# Epoch: 062 - Training loss: 0.1762 - Validation accuracy: 94.12%
# 867 867
# Epoch: 063 - Training loss: 0.1761 - Validation accuracy: 94.12%
# 867 867
# Epoch: 064 - Training loss: 0.1761 - Validation accuracy: 94.12%
# 867 867
# Epoch: 065 - Training loss: 0.1760 - Validation accuracy: 94.12%
# 867 867
# Epoch: 066 - Training loss: 0.1760 - Validation accuracy: 94.12%
# 867 867
# Epoch: 067 - Training loss: 0.1759 - Validation accuracy: 94.12%
# 867 867
# Epoch: 068 - Training loss: 0.1759 - Validation accuracy: 94.12%
# 867 867
# Epoch: 069 - Training loss: 0.1758 - Validation accuracy: 94.12%
# 867 867
# Epoch: 070 - Training loss: 0.1758 - Validation accuracy: 94.12%
# 867 867
# Epoch: 071 - Training loss: 0.1758 - Validation accuracy: 94.12%
# 867 867
# Epoch: 072 - Training loss: 0.1757 - Validation accuracy: 94.12%
# 867 867
# Epoch: 073 - Training loss: 0.1757 - Validation accuracy: 94.12%
# 867 867
# Epoch: 074 - Training loss: 0.1757 - Validation accuracy: 94.12%
# 867 867
# Epoch: 075 - Training loss: 0.1757 - Validation accuracy: 94.12%
# 867 867
# Epoch: 076 - Training loss: 0.1756 - Validation accuracy: 94.12%
# 867 867
# Epoch: 077 - Training loss: 0.1756 - Validation accuracy: 94.12%
# 867 867
# Epoch: 078 - Training loss: 0.1756 - Validation accuracy: 94.12%
# 867 867
# Epoch: 079 - Training loss: 0.1756 - Validation accuracy: 94.12%
# 867 867
# Epoch: 080 - Training loss: 0.1755 - Validation accuracy: 94.12%
# 867 867
# Epoch: 081 - Training loss: 0.1755 - Validation accuracy: 94.12%
# 867 867
# Epoch: 082 - Training loss: 0.1755 - Validation accuracy: 94.12%
# 867 867
# Epoch: 083 - Training loss: 0.1755 - Validation accuracy: 94.12%
# 867 867
# Epoch: 084 - Training loss: 0.1755 - Validation accuracy: 94.12%
# 867 867
# Epoch: 085 - Training loss: 0.1755 - Validation accuracy: 94.12%
# 867 867
# Epoch: 086 - Training loss: 0.1754 - Validation accuracy: 94.12%
# 867 867
# Epoch: 087 - Training loss: 0.1754 - Validation accuracy: 94.12%
# 867 867
# Epoch: 088 - Training loss: 0.1754 - Validation accuracy: 94.12%
# 867 867
# Epoch: 089 - Training loss: 0.1754 - Validation accuracy: 94.12%
# 867 867
# Epoch: 090 - Training loss: 0.1754 - Validation accuracy: 94.12%
# 867 867
# Epoch: 091 - Training loss: 0.1754 - Validation accuracy: 94.12%
# 867 867
# Epoch: 092 - Training loss: 0.1754 - Validation accuracy: 94.12%
# 867 867
# Epoch: 093 - Training loss: 0.1754 - Validation accuracy: 94.12%
# 867 867
# Epoch: 094 - Training loss: 0.1754 - Validation accuracy: 94.12%
# 867 867
# Epoch: 095 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 096 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 097 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 098 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 099 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 100 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 101 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 102 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 103 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 104 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 105 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 106 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 107 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 108 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 109 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 110 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 111 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 112 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 113 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 114 - Training loss: 0.1753 - Validation accuracy: 94.12%
# 867 867
# Epoch: 115 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 116 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 117 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 118 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 119 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 120 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 121 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 122 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 123 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 124 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 125 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 126 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 127 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 128 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 129 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 130 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 131 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 132 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 133 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 134 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 135 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 136 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 137 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 138 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 139 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 140 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 141 - Training loss: 0.1752 - Validation accuracy: 94.12%
# 867 867
# Epoch: 142 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 143 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 144 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 145 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 146 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 147 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 148 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 149 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 150 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 151 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 152 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 153 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 154 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 155 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 156 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 157 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 158 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 159 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 160 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 161 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 162 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 163 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 164 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 165 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 166 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 167 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 168 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 169 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 170 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 171 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 172 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 173 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 174 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 175 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 176 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 177 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 178 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 179 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 180 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 181 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 182 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 183 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 184 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 185 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 186 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 187 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 188 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 189 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 190 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 191 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 192 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 193 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 194 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 195 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 196 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 197 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 198 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 199 - Training loss: 0.1751 - Validation accuracy: 94.12%
# 867 867
# Epoch: 200 - Training loss: 0.1751 - Validation accuracy: 94.12%

# %%
test_acc, test_out, test_pred  = test(data.test_mask)
print(f'Test Accuracy: {test_acc * 100:.2f}%')
# Out:
# Test Accuracy: 94.48%

# %%
out = model(data.x, data.edge_index)
visualize(out, color=data.y)

# %%
from sklearn.metrics import roc_curve, auc
import torch.nn.functional as F

y_true = data.y
y_pred = softmax_x = F.softmax(test_out, dim=1)
y_pred = y_pred[:, 1].detach().numpy()
print(y_pred)

# Generate ROC curve
fpr, tpr, thresholds = roc_curve(y_true, y_pred)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (ROC) curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# [0.05815027 0.05827529 0.05812556 ... 0.00770162 0.00770162 0.00770162]
